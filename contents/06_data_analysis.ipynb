# %% [markdown]
# # 06 - Data Analysis

# %% [markdown]
# ## Import Package

# %%
# Import package as pandas does not ship along as native package
# use pip install pandas if not installed yet, or follow setup guide

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## A Simple Example: How many Pokemon are there for each type?

# %%
dataframe = pd.read_csv("https://raw.githubusercontent.com/KianYang-Lee/pandas-tutorial/main/datasets/Pokemon.csv")
print(dataframe.head())
print(dataframe.describe())
print(dataframe["Type 1"].value_counts())
dataframe["Type 1"].value_counts().plot(kind="barh")
plt.show()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# 50%     70.000000   65.000000     3.00000
# 75%     90.000000   90.000000     5.00000
# max    230.000000  180.000000     6.00000
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %% [markdown]
# ## Analysing by ascending/descending order

# %%
dataframe.sort_values(by="Attack", ascending=False)
# Out:
#        #                     Name   Type 1    Type 2  Total   HP  Attack  \
# 163  150      MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190
# 232  214  HeracrossMega Heracross      Bug  Fighting    600   80     185
# 424  383    GroudonPrimal Groudon   Ground      Fire    770  100     180
# 426  384    RayquazaMega Rayquaza   Dragon    Flying    780  105     180
# 429  386       DeoxysAttack Forme  Psychic       NaN    600   50     180
# ..   ...                      ...      ...       ...    ...  ...     ...
# 139  129                 Magikarp    Water       NaN    200   20      10
# 261  242                  Blissey   Normal       NaN    540  255      10
# 230  213                  Shuckle      Bug      Rock    505   20      10
# 121  113                  Chansey   Normal       NaN    450  250       5
# 488  440                  Happiny   Normal       NaN    220  100       5
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 163      100      154      100    130           1       True
# 232      115       40      105     75           2      False
# 424      160      150       90     90           3       True
# 426      100      180      100    115           3       True
# 429       20      180       20    150           3       True
# ..       ...      ...      ...    ...         ...        ...
# 139       55       15       20     80           1      False
# 261       10       75      135     55           2      False
# 230      230       10      230      5           2      False
# 121        5       35      105     50           1      False
# 488        5       15       65     30           4      False
#
# [800 rows x 13 columns]

# %%
dataframe.sort_values(by="Attack", ascending=True)
# Out:
#        #                     Name   Type 1    Type 2  Total   HP  Attack  \
# 488  440                  Happiny   Normal       NaN    220  100       5
# 121  113                  Chansey   Normal       NaN    450  250       5
# 230  213                  Shuckle      Bug      Rock    505   20      10
# 261  242                  Blissey   Normal       NaN    540  255      10
# 139  129                 Magikarp    Water       NaN    200   20      10
# ..   ...                      ...      ...       ...    ...  ...     ...
# 429  386       DeoxysAttack Forme  Psychic       NaN    600   50     180
# 426  384    RayquazaMega Rayquaza   Dragon    Flying    780  105     180
# 424  383    GroudonPrimal Groudon   Ground      Fire    770  100     180
# 232  214  HeracrossMega Heracross      Bug  Fighting    600   80     185
# 163  150      MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 488        5       15       65     30           4      False
# 121        5       35      105     50           1      False
# 230      230       10      230      5           2      False
# 261       10       75      135     55           2      False
# 139       55       15       20     80           1      False
# ..       ...      ...      ...    ...         ...        ...
# 429       20      180       20    150           3       True
# 426      100      180      100    115           3       True
# 424      160      150       90     90           3       True
# 232      115       40      105     75           2      False
# 163      100      154      100    130           1       True
#
# [800 rows x 13 columns]

# %% [markdown]
# ## Analysing by Single Group

# %%
dataframe.groupby("Type 1").head()
# Out:
#        #                     Name  Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1                Bulbasaur   Grass  Poison    318  45      49       49
# 1      2                  Ivysaur   Grass  Poison    405  60      62       63
# 2      3                 Venusaur   Grass  Poison    525  80      82       83
# 3      3    VenusaurMega Venusaur   Grass  Poison    625  80     100      123
# 4      4               Charmander    Fire     NaN    309  39      52       43
# ..   ...                      ...     ...     ...    ...  ..     ...      ...
# 366  334      AltariaMega Altaria  Dragon   Fairy    590  75     110      110
# 702  641  TornadusIncarnate Forme  Flying     NaN    580  79     115       70
# 703  641    TornadusTherian Forme  Flying     NaN    580  79     100       80
# 790  714                   Noibat  Flying  Dragon    245  40      30       35
# 791  715                  Noivern  Flying  Dragon    535  85      70       80
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 366      110      105     80           3      False
# 702      125       80    111           5       True
# 703      110       90    121           5       True
# 790       45       40     55           6      False
# 791       97       80    123           6      False
#
# [89 rows x 13 columns]

# %%
dataframe.groupby("Type 1").count()
# Out:
#             #  Name  Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Type 1
# Bug        69    69      52     69   69      69       69       69       69
# Dark       31    31      21     31   31      31       31       31       31
# Dragon     32    32      21     32   32      32       32       32       32
# Electric   44    44      17     44   44      44       44       44       44
# Fairy      17    17       2     17   17      17       17       17       17
# Fighting   27    27       7     27   27      27       27       27       27
# Fire       52    52      24     52   52      52       52       52       52
# Flying      4     4       2      4    4       4        4        4        4
# Ghost      32    32      22     32   32      32       32       32       32
# Grass      70    70      37     70   70      70       70       70       70
# Ground     32    32      19     32   32      32       32       32       32
# Ice        24    24      11     24   24      24       24       24       24
# Normal     98    98      37     98   98      98       98       98       98
# Poison     28    28      13     28   28      28       28       28       28
# Psychic    57    57      19     57   57      57       57       57       57
# Rock       44    44      35     44   44      44       44       44       44
# Steel      27    27      22     27   27      27       27       27       27
# Water     112   112      53    112  112     112      112      112      112
#
#           Speed  Generation  Legendary
# Type 1
# Bug          69          69         69
# Dark         31          31         31
# Dragon       32          32         32
# Electric     44          44         44
# Fairy        17          17         17
# Fighting     27          27         27
# Fire         52          52         52
# Flying        4           4          4
# Ghost        32          32         32
# Grass        70          70         70
# Ground       32          32         32
# Ice          24          24         24
# Normal       98          98         98
# Poison       28          28         28
# Psychic      57          57         57
# Rock         44          44         44
# Steel        27          27         27
# Water       112         112        112

# %%
dataframe.groupby("Type 1").HP.mean().sort_values(ascending=False)
# Out:
# Type 1
# Dragon      83.312500
# Normal      77.275510
# Fairy       74.117647
# Ground      73.781250
# Water       72.062500
# Ice         72.000000
# Flying      70.750000
# Psychic     70.631579
# Fire        69.903846
# Fighting    69.851852
# Grass       67.271429
# Poison      67.250000
# Dark        66.806452
# Rock        65.363636
# Steel       65.222222
# Ghost       64.437500
# Electric    59.795455
# Bug         56.884058
# Name: HP, dtype: float64

# %%
dataframe.groupby("Type 1").HP.median().sort_values(ascending=False)
# Out:
# Type 1
# Dragon      80.0
# Flying      79.0
# Fairy       78.0
# Ground      75.0
# Water       70.0
# Normal      70.0
# Fighting    70.0
# Fire        70.0
# Ice         70.0
# Rock        68.5
# Psychic     68.0
# Poison      67.5
# Grass       65.5
# Dark        65.0
# Electric    60.0
# Steel       60.0
# Bug         60.0
# Ghost       59.5
# Name: HP, dtype: float64

# %%
dataframe.groupby("Type 1").HP.max().sort_values(ascending=False)
# Out:
# Type 1
# Normal      255
# Psychic     190
# Water       170
# Ghost       150
# Fighting    144
# Dark        126
# Fairy       126
# Dragon      125
# Rock        123
# Grass       123
# Ground      115
# Fire        115
# Ice         110
# Poison      105
# Steel       100
# Electric     90
# Bug          86
# Flying       85
# Name: HP, dtype: int64

# %% [markdown]
# ## DataFrameGroupBy Object

# %%
# DataFrameGroupByObject can be thought as a resemblance to DataFrame
# and certain functions can be applied on it by using apply method
dataframe.groupby("Type 1").apply(lambda x: x.loc[:, "Name"])
# Out:
# Type 1
# Bug     13       Caterpie
#         14        Metapod
#         15     Butterfree
#         16         Weedle
#         17         Kakuna
#                   ...
# Water   724       Froakie
#         725     Frogadier
#         726      Greninja
#         762     Clauncher
#         763     Clawitzer
# Name: Name, Length: 800, dtype: object

# %%
dataframe.groupby("Type 1").apply(np.sum, axis=0)
# Out:
# C:\Users\KianYang.Lee\miniconda3\envs\pandas-tutorial\lib\site-packages\numpy\core\fromnumeric.py:84: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return reduction(axis=axis, out=out, **passkwargs)
#               #                                               Name  \
# Type 1
# Bug       23080  CaterpieMetapodButterfreeWeedleKakunaBeedrillB...
# Dark      14302  UmbreonMurkrowSneaselHoundourHoundoomHoundoomM...
# Dragon    15180  DratiniDragonairDragoniteAltariaAltariaMega Al...
# Electric  15994  PikachuRaichuMagnemiteMagnetonVoltorbElectrode...
# Fairy      7642  ClefairyClefableCleffaTogepiTogeticSnubbullGra...
# Fighting   9824  MankeyPrimeapeMachopMachokeMachampHitmonleeHit...
# Fire      17025  CharmanderCharmeleonCharizardCharizardMega Cha...
# Flying     2711  TornadusIncarnate FormeTornadusTherian FormeNo...
# Ghost     15568  GastlyHaunterGengarGengarMega GengarMisdreavus...
# Grass     24141  BulbasaurIvysaurVenusaurVenusaurMega VenusaurO...
# Ground    11401  SandshrewSandslashDiglettDugtrioCuboneMarowakR...
# Ice       10165  JynxArticunoSwinubPiloswineDelibirdSmoochumSno...
# Normal    31279  PidgeyPidgeottoPidgeotPidgeotMega PidgeotRatta...
# Poison     7050  EkansArbokNidoran♀NidorinaNidoqueenNidoran♂Nid...
# Psychic   21706  AbraKadabraAlakazamAlakazamMega AlakazamDrowze...
# Rock      17280  GeodudeGravelerGolemOnixOmanyteOmastarKabutoKa...
# Steel     11957  SteelixSteelixMega SteelixSkarmoryMawileMawile...
# Water     33946  SquirtleWartortleBlastoiseBlastoiseMega Blasto...
#
#                                                      Type 1  Total    HP  \
# Type 1
# Bug       BugBugBugBugBugBugBugBugBugBugBugBugBugBugBugB...  26146  3925
# Dark      DarkDarkDarkDarkDarkDarkDarkDarkDarkDarkDarkDa...  13818  2071
# Dragon    DragonDragonDragonDragonDragonDragonDragonDrag...  17617  2666
# Electric  ElectricElectricElectricElectricElectricElectr...  19510  2631
# Fairy     FairyFairyFairyFairyFairyFairyFairyFairyFairyF...   7024  1260
# Fighting  FightingFightingFightingFightingFightingFighti...  11244  1886
# Fire      FireFireFireFireFireFireFireFireFireFireFireFi...  23820  3635
# Flying                             FlyingFlyingFlyingFlying   1940   283
# Ghost     GhostGhostGhostGhostGhostGhostGhostGhostGhostG...  14066  2062
# Grass     GrassGrassGrassGrassGrassGrassGrassGrassGrassG...  29480  4709
# Ground    GroundGroundGroundGroundGroundGroundGroundGrou...  14000  2361
# Ice       IceIceIceIceIceIceIceIceIceIceIceIceIceIceIceI...  10403  1728
# Normal    NormalNormalNormalNormalNormalNormalNormalNorm...  39365  7573
# Poison    PoisonPoisonPoisonPoisonPoisonPoisonPoisonPois...  11176  1883
# Psychic   PsychicPsychicPsychicPsychicPsychicPsychicPsyc...  27129  4026
# Rock      RockRockRockRockRockRockRockRockRockRockRockRo...  19965  2876
# Steel     SteelSteelSteelSteelSteelSteelSteelSteelSteelS...  13168  1761
# Water     WaterWaterWaterWaterWaterWaterWaterWaterWaterW...  48211  8071
#
#           Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Type 1
# Bug         4897     4880     3717     4471   4256         222          0
# Dark        2740     2177     2314     2155   2361         125          2
# Dragon      3588     2764     3099     2843   2657         124         12
# Electric    3040     2917     3961     3243   3718         144          4
# Fairy       1046     1117     1335     1440    826          70          1
# Fighting    2613     1780     1434     1747   1784          91          0
# Fire        4408     3524     4627     3755   3871         167          5
# Flying       315      265      377      290    410          22          2
# Ghost       2361     2598     2539     2447   2059         134          2
# Grass       5125     4956     5425     4930   4335         235          3
# Ground      3064     2715     1807     2008   2045         101          4
# Ice         1746     1714     1861     1831   1523          85          2
# Normal      7200     5865     5470     6245   7012         299          2
# Poison      2091     1927     1692     1803   1780          71          0
# Psychic     4073     3858     5609     4918   4645         193         14
# Rock        4086     4435     2787     3321   2460         152          4
# Steel       2503     3412     1823     2177   1492         104          4
# Water       8305     8170     8379     7898   7388         320          4

# %% [markdown]
# ## Analysing by Multiple Groups

# %%
dataframe.groupby(["Type 1", "Type 2"]).head()
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [348 rows x 13 columns]

# %%
dataframe.groupby(["Type 1", "Type 2"]).Defense.describe()
# Out:
#                  count        mean        std   min    25%    50%     75%  \
# Type 1 Type 2
# Bug    Electric    2.0   55.000000   7.071068  50.0  52.50   55.0   57.50
#        Fighting    2.0   95.000000  28.284271  75.0  85.00   95.0  105.00
#        Fire        2.0   60.000000   7.071068  55.0  57.50   60.0   62.50
#        Flying     14.0   61.571429  25.695598  30.0  46.25   50.0   75.50
#        Ghost       1.0   45.000000        NaN  45.0  45.00   45.0   45.00
# ...                ...         ...        ...   ...    ...    ...     ...
# Water  Ice         3.0  113.333333  57.735027  80.0  80.00   80.0  130.00
#        Poison      3.0   58.333333  20.816660  35.0  50.00   65.0   70.00
#        Psychic     5.0  104.000000  45.469770  65.0  80.00   85.0  110.00
#        Rock        4.0  112.750000  22.896506  85.0  98.50  116.5  130.75
#        Steel       1.0   88.000000        NaN  88.0  88.00   88.0   88.00
#
#                    max
# Type 1 Type 2
# Bug    Electric   60.0
#        Fighting  115.0
#        Fire       65.0
#        Flying    120.0
#        Ghost      45.0
# ...                ...
# Water  Ice       180.0
#        Poison     75.0
#        Psychic   180.0
#        Rock      133.0
#        Steel      88.0
#
# [136 rows x 8 columns]

# %%
dataframe.groupby(["Type 1", "Type 2"]).HP.mean().sort_values(ascending=True)
# Out:
# Type 1   Type 2
# Bug      Ghost         1.000000
# Poison   Bug          40.000000
# Bug      Water        40.000000
# Psychic  Fairy        43.666667
# Bug      Ground       45.500000
#                         ...
# Ground   Electric    109.000000
#          Steel       110.000000
# Ghost    Flying      120.000000
# Dragon   Ice         125.000000
# Ghost    Dragon      150.000000
# Name: HP, Length: 136, dtype: float64

# %% [markdown]
# ## Practice Section

# %% [markdown]
# Using the methods introduced in this notebook, generate insights for the following questions:
# - Do the top 5 Pokemon with highest Attack also have high Defense?
# - What are the top 3 2nd Generation Pokemon with highest Sp. Atk?
# - What are the Pokemon with highest Attack from each Generation?
# - Which Pokemon type ("Type 1") has the highest average Speed?
# - How many Legendary Pokemon is from the 4th Generation?

# %% [markdown]
# **Copyright (C) 2021  Lee Kian Yang**
#
# This program is licensed under MIT license.
